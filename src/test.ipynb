# %%
import pandas as pd

# %%
seasons = pd.read_csv('../data/raw/races.csv')
seasons.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
seasons[seasons.year==2024].head()
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 1101    1121  2024      1          3        Bahrain Grand Prix  2024-03-02
# 1102    1122  2024      2         77  Saudi Arabian Grand Prix  2024-03-09
# 1103    1123  2024      3          1     Australian Grand Prix  2024-03-24
# 1104    1124  2024      4         22       Japanese Grand Prix  2024-04-07
# 1105    1125  2024      5         17        Chinese Grand Prix  2024-04-21
#
#           time                                                url    fp1_date  \
# 1101  15:00:00  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...  2024-02-29
# 1102  17:00:00  https://en.wikipedia.org/wiki/2024_Saudi_Arabi...  2024-03-07
# 1103  04:00:00  https://en.wikipedia.org/wiki/2024_Australian_...  2024-03-22
# 1104  05:00:00  https://en.wikipedia.org/wiki/2024_Japanese_Gr...  2024-04-05
# 1105  07:00:00  https://en.wikipedia.org/wiki/2024_Chinese_Gra...  2024-04-19
#
# ...

# %%
constructors_r = pd.read_csv('../data/raw/constructor_results.csv')
constructors_r = cr[cr.raceId>1120]
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 12385                 16890    1121              9    44.0     \N
# 12386                 16891    1121              6    27.0     \N
# 12387                 16892    1121            131    16.0     \N
# 12388                 16893    1121              1    12.0     \N
# 12389                 16894    1121            117     3.0     \N

# %%
lap_times = pd.read_csv('../data/raw/lap_times.csv')
lap_times = lap_times[lap_times.raceId>1120]
lap_times.head()
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 562507    1121       830    1         1  1:37.284         97284
# 562508    1121       830    2         1  1:36.296         96296
# 562509    1121       830    3         1  1:36.753         96753
# 562510    1121       830    4         1  1:36.647         96647
# 562511    1121       830    5         1  1:37.173         97173

# %%
status = pd.read_csv('../data/raw/status.csv')
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
constructors = pd.read_csv('../data/raw/constructors.csv')
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
